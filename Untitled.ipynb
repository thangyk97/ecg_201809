# %%
# %matplotlib notebook

# %%
# Import package
from biosppy.signals import ecg
import numpy as np
import os
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [14, 8]
from scipy.io import loadmat
folder_path = '/home/thangnd/git/ecg_201809/data/mit/'

# %%
test = loadmat(folder_path + '100m.mat')
test = test['val'][0]
test = test[:30*60*360]
test = np.reshape(test, (60,30*360))
test = np.append(test, np.zeros((60,1)), axis=1)
np.save('/home/thangnd/git/ecg_201809/data/test_normal.npy', test)

# %%
# Load files text

arr = os.listdir(folder_path)
#
evaluate = []
for file_path in arr:
    temp = loadmat(folder_path + file_path)
    evaluate.append(temp)
evaluate = np.array(evaluate)
np.save('/home/thangnd/git/ecg_201809/data/evaluate.npy', evaluate)

# %%
test = loadmat(folder_path + '232m.mat')
test = test['val'][0]

# %%
out_a_con = ecg.ecg(signal=test, sampling_rate=360, show=True)
# Out:
# <img src="data:image/png;base64,..." width="1400">

# %%
35142 / 10800
# Out:
# 3.253888888888889
