# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt
# plt.rcParams['figure.figsize'] = [14, 6]
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from scipy.io import loadmat

# %%
data_path = '/home/thangnd/git/ecg_201809/data/'

data = loadmat(data_path + 'af_challenge/n01m.mat')

# %%
signal = data['val']
sig1 = signal[0]

arr = np.array([sig1[:7680/2], sig1[7680/2:]])
np.save(data_path + 'test2.npy', arr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-8846d4554846> in <module>()
#       2 sig1 = signal[0]
#       3
# ----> 4 arr = np.array([sig1[:7680/2], sig1[7680/2:]])
#       5 np.save(data_path + 'test2.npy', arr)
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %%
plt.plot(sig2)
# Out:
# <img src="data:image/png;base64,..." width="640">
